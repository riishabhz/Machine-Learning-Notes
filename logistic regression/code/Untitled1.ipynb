# %%
import numpy as np
testdata=np.genfromtxt("test.csv",delimiter=",")
traindata=np.genfromtxt("train.csv",delimiter=",")
x=traindata  #here we converted 1d array into 2d array
y=traindata
traindata.shape
from sklearn.linear_model import LogisticRegression as lr
alg=lr()
alg.fit(x,y)
y_pred=alg.predict(testdata)
np.savetxt("predict1.csv",y_pred,fmt= "%.5f")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-5d584c63257f> in <module>()
#       1 import numpy as np
# ----> 2 testdata=np.genfromtxt("test.csv",delimiter=",")
#       3 traindata=np.genfromtxt("train.csv",delimiter=",")
#       4 x=traindata  #here we converted 1d array into 2d array
#       5 y=traindata
#
# E:\anaconda\lib\site-packages\numpy\lib\npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    2029             # Raise an exception ?
#    2030             if invalid_raise:
# -> 2031                 raise ValueError(errmsg)
#    2032             # Issue a warning ?
#    2033             else:
#
# ...

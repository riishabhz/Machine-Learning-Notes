# %%
##TO LOAD DATA FILE (DATA.CSV):-
import numpy as np
data=np.loadtxt("data.csv",delimiter=",")
data.shape
# Out:
# (100, 2)

# %%
#TO SPLIT DATA IN X AND Y :-
import numpy as np
data=np.loadtxt("data.csv",delimiter=",")
x=data[:,0]
y=data[:,1]
x.shape
# Out:
# (100,)

# %%
#split data into training and testing:-
import numpy as np
data=np.loadtxt("data.csv",delimiter=",")
x=data[:,0]
y=data[:,1]
x.shape
from sklearn import model_selection
x_train,x_test,y_train,y_test=model_selection.train_test_split(x,y)

# %%
# create object in linear regression:-
import numpy as np
data=np.loadtxt("data.csv",delimiter=",")
x=data[:,0].reshape(-1,1)   #here we converted 1d array into 2d array
y=data[:,1]
x.shape
from sklearn import model_selection
x_train,x_test,y_train,y_test=model_selection.train_test_split(x,y)
from sklearn.linear_model import LinearRegression
alg1=LinearRegression()
alg1.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# To get coffecient in linear regression i.e m part in y=mx+c :-
import numpy as np
data=np.loadtxt("data.csv",delimiter=",")
x=data[:,0].reshape(-1,1)   #here we converted 1d array into 2d array
y=data[:,1]
x.shape
from sklearn import model_selection
x_train,x_test,y_train,y_test=model_selection.train_test_split(x,y)
from sklearn.linear_model import LinearRegression
alg1=LinearRegression()
alg1.fit(x_train,y_train)
alg1.coef_
# Out:
# array([1.2811645])

# %%
# to get intercept part in linear regression i.e c part in y=mx+c :-

import numpy as np
data=np.loadtxt("data.csv",delimiter=",")
x=data[:,0].reshape(-1,1)   #here we converted 1d array into 2d array
y=data[:,1]
x.shape
from sklearn import model_selection
x_train,x_test,y_train,y_test=model_selection.train_test_split(x,y)
from sklearn.linear_model import LinearRegression
alg1=LinearRegression()
alg1.fit(x_train,y_train)
print(alg1.coef_)
print(alg1.intercept_)
# Out:
# [1.37888887]
# 6.7404089183253575

# %%
# To plot Linear regression line y=mx+c :-

import numpy as np
data=np.loadtxt("data.csv",delimiter=",")
x=data[:,0].reshape(-1,1)   #here we converted 1d array into 2d array
y=data[:,1]
x.shape
from sklearn import model_selection
x_train,x_test,y_train,y_test=model_selection.train_test_split(x,y)
from sklearn.linear_model import LinearRegression
alg1=LinearRegression()
alg1.fit(x_train,y_train)
import matplotlib.pyplot as plt
m=alg1.coef_[0]
c=alg1.intercept_
x_line=np.arange(0,70,0.1) ### line is plotting in range from 0 to 70 with 0.1 differecnce
y_line=m*x_line+c
plt.plot(x_line,y_line)
plt.show()

# %%
# TO scatter training points data in linear regression from csv file :-
import numpy as np
data=np.loadtxt("data.csv",delimiter=",")
x=data[:,0].reshape(-1,1)   #here we converted 1d array into 2d array
y=data[:,1]
x.shape
from sklearn import model_selection
x_train,x_test,y_train,y_test=model_selection.train_test_split(x,y)
from sklearn.linear_model import LinearRegression
alg1=LinearRegression()
alg1.fit(x_train,y_train)
import matplotlib.pyplot as plt
m=alg1.coef_[0]
c=alg1.intercept_
x_line=np.arange(0,100,0.1) ### line is plotting in range from 0 to 70 with 0.1 differecnce
y_line=m*x_line+c
plt.plot(x_line,y_line)
train_1d=x_train.reshape(75)
plt.scatter(x_train,y_train)
plt.show()

# %%
## For testing data :-
import numpy as np
data=np.loadtxt("data.csv",delimiter=",")
x=data[:,0].reshape(-1,1)   #here we converted 1d array into 2d array
y=data[:,1]
x.shape
from sklearn import model_selection
x_train,x_test,y_train,y_test=model_selection.train_test_split(x,y)
from sklearn.linear_model import LinearRegression
alg1=LinearRegression()
alg1.fit(x_train,y_train)
import matplotlib.pyplot as plt
m=alg1.coef_[0]
c=alg1.intercept_
x_line=np.arange(0,100,0.1) ### line is plotting in range from 0 to 70 with 0.1 differecnce
y_line=m*x_line+c
plt.plot(x_line,y_line)
train_1d=x_test.reshape(25)
plt.scatter(x_test,y_test)
plt.show()
